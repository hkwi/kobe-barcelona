# %%
import geopandas as gpd

# %% [markdown]
# 海上に人口がカウントされている例

# %%
f = gpd.read_file("../data/estat/h22ka28105.shp")
f[f["MOJI"].isnull()].T
# Out:
#                                                           190
# AREA                                              6.48949e+06
# AREA_MAX_F                                                  M
# CITY                                                      105
# CSS_NAME                                                  兵庫区
# CSUM                                                        1
# DIR                                                         0
# DUMMY1                                                      -
# GST_NAME                                                  神戸市
# H22KA28_                                                 8402
# H22KA28_ID                                               8401
# H22KA31_                                                    0
# H22KA31_ID                                                  0
# H22KA33_                                                    0
# H22KA33_ID                                                  0
# ...

# %%
# %matplotlib inline

# %%
f.plot()
